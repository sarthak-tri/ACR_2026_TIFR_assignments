# %% [markdown]
# # Exploring simulated data generated with simtel array
#
# Here we will explore the structure of CTA Event files. We will use `h5py` to look at the directory structure and `ctapipe.io.EventSource` to load the same file for future analysis.\
# For a complete description of the dataset used here, refer [CTAO Monte Carlo Simulations - Eventlists on DL2 data level - prod5](https://zenodo.org/records/7298569?)
#
# We will use the publicly available simulations from CTAO

# %%
import numpy as np
import ctapipe
from ctapipe.io import EventSource
import h5py
from pprint import pprint
import matplotlib.pyplot as plt
from ctapipe.utils.datasets import get_dataset_path

#input_file = get_dataset_path("gamma_prod5.simtel.zst")
input_file = (
    "gamma-diffuse_with_images_00.dl2.h5"
)

# %%
with h5py.File(input_file, "r") as f:
    f.visit(print)
f.close()
# Out:
# configuration
# configuration/instrument
# configuration/instrument/subarray
# configuration/instrument/subarray/layout
# configuration/instrument/telescope
# configuration/instrument/telescope/camera
# configuration/instrument/telescope/camera/geometry_0
# configuration/instrument/telescope/camera/geometry_1
# configuration/instrument/telescope/camera/readout_0
# configuration/instrument/telescope/camera/readout_1
# configuration/instrument/telescope/optics
# configuration/observation
# configuration/observation/observation_block
# configuration/observation/scheduling_block
# configuration/simulation
# configuration/simulation/run
# dl1
# dl1/event
# dl1/event/subarray
# dl1/event/subarray/trigger
# dl1/event/telescope
# dl1/event/telescope/images
# dl1/event/telescope/images/tel_001
# dl1/event/telescope/images/tel_002
# dl1/event/telescope/images/tel_003
# dl1/event/telescope/images/tel_004
# dl1/event/telescope/images/tel_005
# dl1/event/telescope/images/tel_006
# dl1/event/telescope/images/tel_007
# dl1/event/telescope/images/tel_008
# dl1/event/telescope/images/tel_009
# dl1/event/telescope/images/tel_010
# dl1/event/telescope/images/tel_011
# dl1/event/telescope/images/tel_019
# dl1/event/telescope/images/tel_035
# dl1/event/telescope/parameters
# dl1/event/telescope/parameters/tel_001
# dl1/event/telescope/parameters/tel_002
# dl1/event/telescope/parameters/tel_003
# dl1/event/telescope/parameters/tel_004
# dl1/event/telescope/parameters/tel_005
# dl1/event/telescope/parameters/tel_006
# dl1/event/telescope/parameters/tel_007
# dl1/event/telescope/parameters/tel_008
# dl1/event/telescope/parameters/tel_009
# dl1/event/telescope/parameters/tel_010
# dl1/event/telescope/parameters/tel_011
# dl1/event/telescope/parameters/tel_019
# dl1/event/telescope/parameters/tel_035
# dl1/event/telescope/trigger
# dl1/monitoring
# dl1/monitoring/subarray
# dl1/monitoring/subarray/pointing
# dl1/monitoring/telescope
# dl1/monitoring/telescope/pointing
# dl1/monitoring/telescope/pointing/tel_001
# dl1/monitoring/telescope/pointing/tel_002
# dl1/monitoring/telescope/pointing/tel_003
# dl1/monitoring/telescope/pointing/tel_004
# dl1/monitoring/telescope/pointing/tel_005
# dl1/monitoring/telescope/pointing/tel_006
# dl1/monitoring/telescope/pointing/tel_007
# dl1/monitoring/telescope/pointing/tel_008
# dl1/monitoring/telescope/pointing/tel_009
# dl1/monitoring/telescope/pointing/tel_010
# dl1/monitoring/telescope/pointing/tel_011
# dl1/monitoring/telescope/pointing/tel_019
# dl1/monitoring/telescope/pointing/tel_035
# dl1/service
# dl1/service/image_statistics
# dl2
# dl2/event
# dl2/event/subarray
# dl2/event/subarray/geometry
# dl2/event/subarray/geometry/HillasReconstructor
# dl2/event/telescope
# dl2/event/telescope/impact
# dl2/event/telescope/impact/HillasReconstructor
# dl2/event/telescope/impact/HillasReconstructor/tel_001
# dl2/event/telescope/impact/HillasReconstructor/tel_002
# dl2/event/telescope/impact/HillasReconstructor/tel_003
# dl2/event/telescope/impact/HillasReconstructor/tel_004
# dl2/event/telescope/impact/HillasReconstructor/tel_005
# dl2/event/telescope/impact/HillasReconstructor/tel_006
# dl2/event/telescope/impact/HillasReconstructor/tel_007
# dl2/event/telescope/impact/HillasReconstructor/tel_008
# dl2/event/telescope/impact/HillasReconstructor/tel_009
# dl2/event/telescope/impact/HillasReconstructor/tel_010
# dl2/event/telescope/impact/HillasReconstructor/tel_011
# dl2/event/telescope/impact/HillasReconstructor/tel_019
# dl2/event/telescope/impact/HillasReconstructor/tel_035
# dl2/service
# dl2/service/tel_event_statistics
# dl2/service/tel_event_statistics/HillasReconstructor
# simulation
# simulation/event
# simulation/event/subarray
# simulation/event/subarray/shower
# simulation/event/telescope
# simulation/event/telescope/images
# simulation/event/telescope/images/tel_001
# simulation/event/telescope/images/tel_002
# simulation/event/telescope/images/tel_003
# simulation/event/telescope/images/tel_004
# simulation/event/telescope/images/tel_005
# simulation/event/telescope/images/tel_006
# simulation/event/telescope/images/tel_007
# simulation/event/telescope/images/tel_008
# simulation/event/telescope/images/tel_009
# simulation/event/telescope/images/tel_010
# simulation/event/telescope/images/tel_011
# simulation/event/telescope/images/tel_019
# simulation/event/telescope/images/tel_035
# simulation/event/telescope/impact
# simulation/event/telescope/impact/tel_001
# simulation/event/telescope/impact/tel_002
# simulation/event/telescope/impact/tel_003
# simulation/event/telescope/impact/tel_004
# simulation/event/telescope/impact/tel_005
# simulation/event/telescope/impact/tel_006
# simulation/event/telescope/impact/tel_007
# simulation/event/telescope/impact/tel_008
# simulation/event/telescope/impact/tel_009
# simulation/event/telescope/impact/tel_010
# simulation/event/telescope/impact/tel_011
# simulation/event/telescope/impact/tel_019
# simulation/event/telescope/impact/tel_035
# simulation/event/telescope/parameters
# simulation/event/telescope/parameters/tel_001
# simulation/event/telescope/parameters/tel_002
# simulation/event/telescope/parameters/tel_003
# simulation/event/telescope/parameters/tel_004
# simulation/event/telescope/parameters/tel_005
# simulation/event/telescope/parameters/tel_006
# simulation/event/telescope/parameters/tel_007
# simulation/event/telescope/parameters/tel_008
# simulation/event/telescope/parameters/tel_009
# simulation/event/telescope/parameters/tel_010
# simulation/event/telescope/parameters/tel_011
# simulation/event/telescope/parameters/tel_019
# simulation/event/telescope/parameters/tel_035
# simulation/service
# simulation/service/shower_distribution

# %% [markdown]
# #### Directory Structure Summarized
# <pre>
# configuration/
# |--> instrument/
# |    |--> subarray/
# |    |    |--> layout
# |    |--> telescope/
# |         |--> camera/
# |         |    |--> geometry (0,1)
# |         |    |--> readout (0,1)
# |         |--> optics
# |--> observation/
# |    |--> observation_block
# |    |--> scheduling_block
# |--> simulation/
#      |--> run
#
# dl1/
# |--> event/
# |    |--> subarray/
# |    |    |--> trigger
# |    |--> telescope/
# |         |--> images/
# |         |    |--> tel_XXX
# |         |--> parameters/
# |         |    |--> tel_XXX
# |         |--> trigger
# |--> monitoring/
# |    |--> subarray/
# |    |     |--> pointing
# |    |--> telescope/
# |         |--> pointing/
# |              |--> tel_XXX
# |--> service/
#      |--> image_statistics
#
# dl2/
# |--> event/
# |    |--> subarray/
# |    |    |--> geometry/
# |    |         |--> HillasReconstructor
# |    |--> telescope/
# |         |--> impact/
# |              |--> HillasReconstructor/
# |                   |--> tel_XXX
# |── service/
#     |--> tel_event_statistics/
#          |--> HillasReconstructor
#
# simulation/
# |--> event/
# |    |--> subarray/
# |    |    |--> shower
# |    |--> telescope/
# |         |--> images/
# |         |    |--> tel_XXX
# |         |--> impact/
# |         |    |--> tel_XXX
# |         |--> parameters/
# |              |--> tel_XXX
# |── service/
#     |--> shower_distribution
# </pre>
# ---

# %% [markdown]
# We create an instance of the `ctapipe.io.EventSource` that reads the input file and generate `ArrayEventContainer` instances iterated over each event.
# This is a top level container for all event info. The `EventSource` instance creates an `ArrayEventController` for each event that contains the index, dl1, dl2, simulation and trigger information

# %%
source = EventSource(
    input_url=input_file,
    max_events = None 
)
# Out:
# Table /configuration/simulation/run is missing column None for field run_number of container <class 'ctapipe.containers.SimulationConfigContainer'>. It will be skipped.

# %%
source
# Out:
# <div style="border:1px solid black; max-width: 700px; padding:2em; word-wrap:break-word;">
# <b>HDF5EventSource</b>
# <div class="document">
# <p>Event source for files in the ctapipe DL1 format.
# For general information about the concept of event sources,
# take a look at the parent class ctapipe.io.EventSource.</p>
# <p>To use this event source, create an instance of this class
# specifying the file to be read.</p>
# <p>Looping over the EventSource yields events from the _generate_events
# method. An event equals an ArrayEventContainer instance.
# See ctapipe.containers.ArrayEventContainer for details.</p>
# <div class="section" id="attributes">
# <h1>Attributes</h1>
# <dl class="docutils">
# <dt>input_url: str</dt>
# <dd>Path to the input event file.</dd>
# <dt>file: tables.File</dt>
# <dd>File object</dd>
# <dt>obs_ids: list</dt>
# <dd>Observation ids of the recorded runs. For unmerged files, this
# should only contain a single number.</dd>
# <dt>subarray: ctapipe.instrument.SubarrayDescription</dt>
# <dd>The subarray configuration of the recorded run.</dd>
# <dt>datalevels: Tuple</dt>
# <dd>One or both of ctapipe.io.datalevels.DataLevel.DL1_IMAGES
# and ctapipe.io.datalevels.DataLevel.DL1_PARAMETERS
# depending on the information present in the file.</dd>
# <dt>is_simulation: Boolean</dt>
# <dd>Whether the events are simulated or observed.</dd>
# <dt>simulation_configs: Dict</dt>
# <dd>Mapping of obs_id to ctapipe.containers.SimulationConfigContainer
# if the file contains simulated events.</dd>
# <dt>has_simulated_dl1: Boolean</dt>
# <dd>Whether the file contains simulated camera images and/or
# image parameters evaluated on these.</dd>
# </dl>
# </div>
# </div>
#
# <table>
#     <colgroup>
#         <col span='1' style=' '>
#         <col span='1' style='width: 20em;'>
#         <col span='1' >
#     </colgroup>
#     <tbody>
# <tr><th>allowed_tels</th>
# <td style="text-align: left;">None</td>
# <td style="text-align: left;"><i>list of allowed tel_ids, others will be ignored. If None, all telescopes in the input stream will be included (default: None)</i></td></tr>
# <tr><th>focal_length_choice</th>
# <td style="text-align: left;">FocalLengthKind.EFFECTIVE</td>
# <td style="text-align: left;"><i>If both nominal and effective focal lengths are available,  which one to use for the `~ctapipe.coordinates.CameraFrame` attached to the `~ctapipe.instrument.CameraGeometry` instances in the `~ctapipe.instrument.SubarrayDescription` which will be used in CameraFrame to TelescopeFrame coordinate transforms. The &#x27;nominal&#x27; focal length is the one used during  the simulation, the &#x27;effective&#x27; focal length is computed using specialized  ray-tracing from a point light source (default: FocalLengthKind.EFFECTIVE)</i></td></tr>
# <tr><th>input_url</th>
# <td style="text-align: left;"><span style="color:blue; max-width:30em;">/<wbr>home/<wbr>atreyeesinha/<wbr>Work/<wbr>SINP_<wbr>ctapipe_<wbr>handson/<wbr>gamma-diffuse_<wbr>with_<wbr>images_<wbr>00.dl2.h5</span></td>
# <td style="text-align: left;"><i>Path to the input file containing events. (default: None)</i></td></tr>
# <tr><th>max_events</th>
# <td style="text-align: left;">None</td>
# <td style="text-align: left;"><i>Maximum number of events that will be read from the file (default: None)</i></td></tr>
#     </tbody>
# </table>
# </div>

# %% [markdown]
# Accessing the telescope description: \
# The simulation made use of 15 telescopes of the CTA Northern Array consisting of 4 LST Cams and 9 MST Cams

# %%
tel_dict = source.subarray.tel
pprint(tel_dict)
# Out:
# {np.int16(1): TelescopeDescription(type='LST', optics_name='LST', camera_name='LSTCam'),
#  np.int16(2): TelescopeDescription(type='LST', optics_name='LST', camera_name='LSTCam'),
#  np.int16(3): TelescopeDescription(type='LST', optics_name='LST', camera_name='LSTCam'),
#  np.int16(4): TelescopeDescription(type='LST', optics_name='LST', camera_name='LSTCam'),
#  np.int16(5): TelescopeDescription(type='MST', optics_name='MST', camera_name='NectarCam'),
#  np.int16(6): TelescopeDescription(type='MST', optics_name='MST', camera_name='NectarCam'),
#  np.int16(7): TelescopeDescription(type='MST', optics_name='MST', camera_name='NectarCam'),
#  np.int16(8): TelescopeDescription(type='MST', optics_name='MST', camera_name='NectarCam'),
#  np.int16(9): TelescopeDescription(type='MST', optics_name='MST', camera_name='NectarCam'),
#  np.int16(10): TelescopeDescription(type='MST', optics_name='MST', camera_name='NectarCam'),
#  np.int16(11): TelescopeDescription(type='MST', optics_name='MST', camera_name='NectarCam'),
#  np.int16(19): TelescopeDescription(type='MST', optics_name='MST', camera_name='NectarCam'),
#  np.int16(35): TelescopeDescription(type='MST', optics_name='MST', camera_name='NectarCam')}

# %%
# Create an iterator for the events in the source
event_iter = iter(source)
event = next(event_iter)
# Out:
# Table /dl1/event/telescope/trigger is missing column event_type for field event_type of container <class 'ctapipe.containers.TelescopeTriggerContainer'>. It will be skipped.
# Table /simulation/event/subarray/shower is missing column true_starting_grammage for field starting_grammage of container <class 'ctapipe.containers.SimulatedShowerContainer'>. It will be skipped.
# Table /dl2/event/subarray/geometry/HillasReconstructor is missing column HillasReconstructor_ang_distance_uncert for field ang_distance_uncert of container <class 'ctapipe.containers.ReconstructedGeometryContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_035 is missing column hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_035 is missing column hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_035 is missing column true_hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_035 is missing column true_hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.

# %% [markdown]
# Structure of the `ArrayEventContainer`

# %%
event
# Out:
# ctapipe.containers.ArrayEventContainer:
#                        index.*: event indexing information with default None
#                           r0.*: Raw Data with default None
#                           r1.*: R1 Calibrated Data with default None
#                          dl0.*: DL0 Data Volume Reduced Data with default None
#                          dl1.*: DL1 Calibrated image with default None
#                          dl2.*: DL2 reconstruction info with default None
#                   simulation.*: Simulated Event Information with default None
#                                 with type <class
#                                 'ctapipe.containers.SimulatedEventContainer'>
#                      trigger.*: central trigger information with default None
#                          count: number of events processed with default 0
#                   monitoring.*: container for event-wise monitoring data (MON)
#                                 with default None
#                         muon.*: Container for muon analysis results with default
#                                 None

# %%
event.index
# Out:
# ctapipe.containers.EventIndexContainer:
#                         obs_id: Observation Block ID with default
#                                 18446744073709551615
#                       event_id: Array Event ID with default 18446744073709551615

# %%
event.r0
# Out:
# ctapipe.containers.R0Container:
#                         tel[*]: map of tel_id to R0CameraContainer with default
#                                 None

# %%
event.r0.meta
# Out:
# {}

# %% [markdown]
# `dl1` contains the calibrated image and `dl2` has the reconstructed parameters. `simulation` contains the shower simulation parameters
# Refer to [ctapipe documentation](https://ctapipe.readthedocs.io/en/latest/user-guide/data_format/index.html) for more details

# %%
print(event.dl1)
# Out:
# {'tel': {np.int16(35): {'image': array([-1.4, -1.1, -0.2, ...,  1.3,  1.6, -0.3],
#       shape=(1855,), dtype=float32),
#                         'image_mask': array([False, False, False, ..., False, False, False], shape=(1855,)),
#                         'is_valid': np.True_,
#                         'parameters': {'concentration': {'cog': np.float64(0.2270637181737781),
#                                                          'core': np.float64(0.2270637181737781),
#                                                          'pixel': np.float64(0.17538581853673704)},
#                                        'core': {'psi': <Quantity nan deg>},
#                                        'hillas': {'fov_lat': <Quantity 2.05479064 deg>,
#                                                   'fov_lon': <Quantity 3.2633547 deg>,
#                                                   'intensity': np.float64(98.05524969100952),
#                                                   'kurtosis': np.float64(1.5651874135696624),
#                                                   'length': <Quantity 0.25584254 deg>,
#                                                   'length_uncertainty': <Quantity 0.00971189 deg>,
#                                                   'phi': <Quantity 32.19681312 deg>,
#                                                   'psi': <Quantity 88.51910626 deg>,
#                                                   'psi_uncertainty': None,
#                                                   'r': <Quantity 3.85637764 deg>,
#                                                   'skewness': np.float64(-0.04988371840841714),
#                                                   'transverse_cog_uncertainty': None,
#                                                   'width': <Quantity 0.06262016 deg>,
#                                                   'width_uncertainty': <Quantity 0.00291945 deg>},
#                                        'intensity_statistics': {'kurtosis': np.float64(-1.3280683755874634),
#                                                                 'max': np.float32(17.1975),
#                                                                 'mean': np.float32(12.256906),
#                                                                 'min': np.float32(7.8907075),
#                                                                 'skewness': np.float64(0.25837427377700806),
#                                                                 'std': np.float32(3.112932)},
#                                        'leakage': {'intensity_width_1': np.float32(0.5148868),
#                                                    'intensity_width_2': np.float32(1.0),
#                                                    'pixels_width_1': np.float64(0.0026954177897574125),
#                                                    'pixels_width_2': np.float64(0.00431266846361186)},
#                                        'morphology': {'n_islands': np.int64(1),
#                                                       'n_large_islands': np.int64(0),
#                                                       'n_medium_islands': np.int64(1),
#                                                       'n_pixels': np.int64(8),
#                                                       'n_small_islands': np.int64(0)},
#                                        'peak_time_statistics': {'kurtosis': np.float64(-1.5963536500930786),
#                                                                 'max': np.float32(23.17393),
#                                                                 'mean': np.float32(17.876595),
#                                                                 'min': np.float32(13.688003),
#                                                                 'skewness': np.float64(0.22608861327171326),
#                                                                 'std': np.float32(3.6868134)},
#                                        'timing': {'deviation': np.float64(1.001435073698692),
#                                                   'intercept': np.float64(17.474885152229415),
#                                                   'slope': <Quantity -14.79448233 1 / deg>}},
#                         'peak_time': array([34.53,  6.69, 60.21, ..., 48.93, 49.26, 39.03],
#       shape=(1855,), dtype=float32)}}}

# %%
print(event.simulation)
# Out:
# {'shower': {'alt': <Quantity 78.50238307 deg>,
#             'az': <Quantity 17.19268751 deg>,
#             'core_x': <Quantity 511.62863159 m>,
#             'core_y': <Quantity -295.44650269 m>,
#             'energy': <Quantity 19.67578125 TeV>,
#             'h_first_int': <Quantity 19403.3046875 m>,
#             'shower_primary_id': np.int64(0),
#             'starting_grammage': None,
#             'x_max': <Quantity 473.64755249 g / cm2>},
#  'tel': {np.int16(35): {'impact': {'distance': <Quantity 492.57461588 m>,
#                                    'distance_uncert': <Quantity 0. m>},
#                         'true_image': array([1, 1, 0, ..., 0, 0, 0], shape=(1855,), dtype=int32),
#                         'true_image_sum': 801,
#                         'true_parameters': {'concentration': {'cog': np.float64(0.019975031210986267),
#                                                               'core': np.float64(0.4681647940074906),
#                                                               'pixel': np.float64(0.02871410736579276)},
#                                             'core': {'psi': <Quantity nan deg>},
#                                             'hillas': {'fov_lat': <Quantity 0.74928163 deg>,
#                                                        'fov_lon': <Quantity 3.06819603 deg>,
#                                                        'intensity': np.float64(801.0),
#                                                        'kurtosis': np.float64(2.384814364299039),
#                                                        'length': <Quantity 1.24728403 deg>,
#                                                        'length_uncertainty': <Quantity 0.02593074 deg>,
#                                                        'phi': <Quantity 13.72354792 deg>,
#                                                        'psi': <Quantity 87.79277442 deg>,
#                                                        'psi_uncertainty': None,
#                                                        'r': <Quantity 3.15836189 deg>,
#                                                        'skewness': np.float64(-0.5380454028913757),
#                                                        'transverse_cog_uncertainty': None,
#                                                        'width': <Quantity 0.53027767 deg>,
#                                                        'width_uncertainty': <Quantity 0.04099727 deg>},
#                                             'intensity_statistics': {'kurtosis': np.float64(5.863877835106159),
#                                                                      'max': np.int32(23),
#                                                                      'mean': np.float64(3.869565217391304),
#                                                                      'min': np.int32(1),
#                                                                      'skewness': np.float64(2.2430303301567345),
#                                                                      'std': np.float64(3.8869770557877135)},
#                                             'leakage': {'intensity_width_1': np.float64(0.1735330836454432),
#                                                         'intensity_width_2': np.float64(0.3682896379525593),
#                                                         'pixels_width_1': np.float64(0.014555256064690027),
#                                                         'pixels_width_2': np.float64(0.030727762803234502)},
#                                             'morphology': {'n_islands': np.int64(23),
#                                                            'n_large_islands': np.int64(1),
#                                                            'n_medium_islands': np.int64(3),
#                                                            'n_pixels': np.int64(207),
#                                                            'n_small_islands': np.int64(19)},
#                                             'peak_time_statistics': {'kurtosis': nan,
#                                                                      'max': np.float32(nan),
#                                                                      'mean': np.float32(nan),
#                                                                      'min': np.float32(nan),
#                                                                      'skewness': nan,
#                                                                      'std': np.float32(nan)},
#                                             'timing': {'deviation': nan,
#                                                        'intercept': nan,
#                                                        'slope': <Quantity nan 1 / deg>}}}}}

# %% [markdown]
# The telescope id and the image of the event is accessed through the dl1 sub-container.\
# The corresponding telescope geometry is situated in the subarray

# %% [markdown]
# #event = next(event_iter)
# tel_id = list(event.dl1.tel.keys())[1]
# tel_geo = source.subarray.tel[tel_id].camera.geometry
# print(tel_geo)
# image = event.dl1.tel[tel_id].image
#
# from ctapipe.visualization import CameraDisplay
# disp = CameraDisplay(tel_geo)
# disp.image = image

# %%
# Out:
# (<DataLevel.DL1_IMAGES: 5>, <DataLevel.DL1_PARAMETERS: 6>, <DataLevel.DL2: 7>)

# %% [markdown]
# The simulation configuration of all observations can be accessed via `EventSource.simulation_config`

# %%
sim_cfg = next(iter(source.simulation_config.values()))
print(sim_cfg)
# Out:
# {'atmosphere': np.int64(99),
#  'core_pos_mode': np.int64(1),
#  'corsika_bunchsize': np.float64(5.0),
#  'corsika_high_E_detail': np.int64(303),
#  'corsika_high_E_model': np.int64(3),
#  'corsika_iact_options': np.int64(187),
#  'corsika_low_E_detail': np.int64(0),
#  'corsika_low_E_model': np.int64(2),
#  'corsika_version': np.int64(7710),
#  'corsika_wlen_max': <Quantity 900. nm>,
#  'corsika_wlen_min': <Quantity 240. nm>,
#  'detector_prog_id': np.int64(1),
#  'detector_prog_start': np.int64(1606278093),
#  'diffuse': np.int64(1),
#  'energy_range_max': <Quantity 330. TeV>,
#  'energy_range_min': <Quantity 0.003 TeV>,
#  'max_alt': <Quantity 1.2217305 rad>,
#  'max_az': <Quantity -6.770173e-08 rad>,
#  'max_scatter_range': <Quantity 1900. m>,
#  'max_viewcone_radius': <Quantity 10. deg>,
#  'min_alt': <Quantity 1.2217305 rad>,
#  'min_az': <Quantity -6.770173e-08 rad>,
#  'min_scatter_range': <Quantity 0. m>,
#  'min_viewcone_radius': <Quantity 0. deg>,
#  'n_showers': np.int64(50000),
#  'prod_site_B_declination': <Quantity -0.07534063 rad>,
#  'prod_site_B_inclination': <Quantity 0.64818996 rad>,
#  'prod_site_B_total': <Quantity 38.77302551 uT>,
#  'prod_site_alt': <Quantity 2158. m>,
#  'run_number': None,
#  'shower_prog_id': np.int64(1),
#  'shower_prog_start': np.int64(1606305600),
#  'shower_reuse': np.int64(20),
#  'simtel_version': np.int64(1593349643),
#  'spectral_index': np.float64(-2.0)}

# %% [markdown]
# The histograms of the spatial distribution of the shower cores and the energy distribution of the showers can be accessed through `EventSource.simulated_shower_distribution`

# %%
obs_id = source.obs_ids[0]

dist = source.simulated_shower_distributions[obs_id]

print(source.simulated_shower_distributions.keys())
# Out:
# dict_keys([np.int32(5712), np.int32(5723), np.int32(5725), np.int32(5726), np.int32(5733), np.int32(5737), np.int32(5740), np.int32(5747), np.int32(5756), np.int32(5762), np.int32(5763), np.int32(5765), np.int32(5766), np.int32(5772), np.int32(5776), np.int32(5778), np.int32(5779), np.int32(5781), np.int32(5782), np.int32(5784), np.int32(5785), np.int32(5786), np.int32(5787), np.int32(5793), np.int32(5794), np.int32(5800), np.int32(5802), np.int32(5805), np.int32(5810), np.int32(5815), np.int32(5817), np.int32(5818), np.int32(5827), np.int32(5829), np.int32(5841), np.int32(5845), np.int32(5846), np.int32(5851), np.int32(5861), np.int32(5863), np.int32(5872), np.int32(5876), np.int32(5877), np.int32(5879), np.int32(5883), np.int32(5887), np.int32(5901), np.int32(5905), np.int32(5906), np.int32(5912)])

# %%
source.simulated_shower_distributions
# Out:
# {np.int32(5712): ctapipe.containers.SimulatedShowerDistribution:
#                          obs_id: Observation Block ID with default
#                                  18446744073709551615
#                         hist_id: Histogram ID with default -1
#                       n_entries: Number of entries in the histogram with default
#                                  -1
#                     bins_energy: array of energy bin lower edges, as in
#                                  np.histogram with default None [TeV]
#                  bins_core_dist: array of core-distance bin lower edges, as in
#                                  np.histogram with default None [m]
#                       histogram: array of histogram entries, size (n_bins_x,
#                                  n_bins_y) with default None,
#  np.int32(5723): ctapipe.containers.SimulatedShowerDistribution:
#                          obs_id: Observation Block ID with default
#                                  18446744073709551615
#                         hist_id: Histogram ID with default -1
#                       n_entries: Number of entries in the histogram with default
#                                  -1
#                     bins_energy: array of energy bin lower edges, as in
#                                  np.histogram with default None [TeV]
#                  bins_core_dist: array of core-distance bin lower edges, as in
#                                  np.histogram with default None [m]
#                       histogram: array of histogram entries, size (n_bins_x,
#                                  n_bins_y) with default None,
#  np.int32(5725): ctapipe.containers.SimulatedShowerDistribution:
#                          obs_id: Observation Block ID with default
#                                  18446744073709551615
#                         hist_id: Histogram ID with default -1
#                       n_entries: Number of entries in the histogram with default
#                                  -1
#                     bins_energy: array of energy bin lower edges, as in
#                                  np.histogram with default None [TeV]
#                  bins_core_dist: array of core-distance bin lower edges, as in
#                                  np.histogram with default None [m]
#                       histogram: array of histogram entries, size (n_bins_x,
#                                  n_bins_y) with default None,
#  np.int32(5726): ctapipe.containers.SimulatedShowerDistribution:
#                          obs_id: Observation Block ID with default
#                                  18446744073709551615
#                         hist_id: Histogram ID with default -1
#                       n_entries: Number of entries in the histogram with default
#                                  -1
#                     bins_energy: array of energy bin lower edges, as in
#                                  np.histogram with default None [TeV]
#                  bins_core_dist: array of core-distance bin lower edges, as in
#                                  np.histogram with default None [m]
#                       histogram: array of histogram entries, size (n_bins_x,
#                                  n_bins_y) with default None,
#  np.int32(5733): ctapipe.containers.SimulatedShowerDistribution:
#                          obs_id: Observation Block ID with default
#                                  18446744073709551615
#                         hist_id: Histogram ID with default -1
#                       n_entries: Number of entries in the histogram with default
#                                  -1
#                     bins_energy: array of energy bin lower edges, as in
#                                  np.histogram with default None [TeV]
#                  bins_core_dist: array of core-distance bin lower edges, as in
#                                  np.histogram with default None [m]
#                       histogram: array of histogram entries, size (n_bins_x,
#                                  n_bins_y) with default None,
#  np.int32(5737): ctapipe.containers.SimulatedShowerDistribution:
#                          obs_id: Observation Block ID with default
#                                  18446744073709551615
#                         hist_id: Histogram ID with default -1
#                       n_entries: Number of entries in the histogram with default
#                                  -1
#                     bins_energy: array of energy bin lower edges, as in
#                                  np.histogram with default None [TeV]
#                  bins_core_dist: array of core-distance bin lower edges, as in
#                                  np.histogram with default None [m]
#                       histogram: array of histogram entries, size (n_bins_x,
#                                  n_bins_y) with default None,
#  np.int32(5740): ctapipe.containers.SimulatedShowerDistribution:
#                          obs_id: Observation Block ID with default
#                                  18446744073709551615
#                         hist_id: Histogram ID with default -1
#                       n_entries: Number of entries in the histogram with default
#                                  -1
#                     bins_energy: array of energy bin lower edges, as in
#                                  np.histogram with default None [TeV]
#                  bins_core_dist: array of core-distance bin lower edges, as in
#                                  np.histogram with default None [m]
#                       histogram: array of histogram entries, size (n_bins_x,
#                                  n_bins_y) with default None,
#  np.int32(5747): ctapipe.containers.SimulatedShowerDistribution:
#                          obs_id: Observation Block ID with default
#                                  18446744073709551615
#                         hist_id: Histogram ID with default -1
#                       n_entries: Number of entries in the histogram with default
#                                  -1
#                     bins_energy: array of energy bin lower edges, as in
#                                  np.histogram with default None [TeV]
#                  bins_core_dist: array of core-distance bin lower edges, as in
#                                  np.histogram with default None [m]
#                       histogram: array of histogram entries, size (n_bins_x,
#                                  n_bins_y) with default None,
#  np.int32(5756): ctapipe.containers.SimulatedShowerDistribution:
#                          obs_id: Observation Block ID with default
#                                  18446744073709551615
#                         hist_id: Histogram ID with default -1
#                       n_entries: Number of entries in the histogram with default
#                                  -1
#                     bins_energy: array of energy bin lower edges, as in
#                                  np.histogram with default None [TeV]
#                  bins_core_dist: array of core-distance bin lower edges, as in
#                                  np.histogram with default None [m]
#                       histogram: array of histogram entries, size (n_bins_x,
#                                  n_bins_y) with default None,
#  np.int32(5762): ctapipe.containers.SimulatedShowerDistribution:
#                          obs_id: Observation Block ID with default
#                                  18446744073709551615
#                         hist_id: Histogram ID with default -1
#                       n_entries: Number of entries in the histogram with default
#                                  -1
#                     bins_energy: array of energy bin lower edges, as in
#                                  np.histogram with default None [TeV]
#                  bins_core_dist: array of core-distance bin lower edges, as in
#                                  np.histogram with default None [m]
#                       histogram: array of histogram entries, size (n_bins_x,
#                                  n_bins_y) with default None,
#  np.int32(5763): ctapipe.containers.SimulatedShowerDistribution:
#                          obs_id: Observation Block ID with default
#                                  18446744073709551615
#                         hist_id: Histogram ID with default -1
#                       n_entries: Number of entries in the histogram with default
#                                  -1
#                     bins_energy: array of energy bin lower edges, as in
#                                  np.histogram with default None [TeV]
#                  bins_core_dist: array of core-distance bin lower edges, as in
#                                  np.histogram with default None [m]
#                       histogram: array of histogram entries, size (n_bins_x,
#                                  n_bins_y) with default None,
#  np.int32(5765): ctapipe.containers.SimulatedShowerDistribution:
#                          obs_id: Observation Block ID with default
#                                  18446744073709551615
#                         hist_id: Histogram ID with default -1
#                       n_entries: Number of entries in the histogram with default
#                                  -1
#                     bins_energy: array of energy bin lower edges, as in
#                                  np.histogram with default None [TeV]
#                  bins_core_dist: array of core-distance bin lower edges, as in
#                                  np.histogram with default None [m]
#                       histogram: array of histogram entries, size (n_bins_x,
#                                  n_bins_y) with default None,
#  np.int32(5766): ctapipe.containers.SimulatedShowerDistribution:
#                          obs_id: Observation Block ID with default
#                                  18446744073709551615
#                         hist_id: Histogram ID with default -1
#                       n_entries: Number of entries in the histogram with default
#                                  -1
#                     bins_energy: array of energy bin lower edges, as in
#                                  np.histogram with default None [TeV]
#                  bins_core_dist: array of core-distance bin lower edges, as in
#                                  np.histogram with default None [m]
#                       histogram: array of histogram entries, size (n_bins_x,
#                                  n_bins_y) with default None,
#  np.int32(5772): ctapipe.containers.SimulatedShowerDistribution:
#                          obs_id: Observation Block ID with default
#                                  18446744073709551615
#                         hist_id: Histogram ID with default -1
#                       n_entries: Number of entries in the histogram with default
#                                  -1
#                     bins_energy: array of energy bin lower edges, as in
#                                  np.histogram with default None [TeV]
#                  bins_core_dist: array of core-distance bin lower edges, as in
#                                  np.histogram with default None [m]
#                       histogram: array of histogram entries, size (n_bins_x,
#                                  n_bins_y) with default None,
#  np.int32(5776): ctapipe.containers.SimulatedShowerDistribution:
#                          obs_id: Observation Block ID with default
#                                  18446744073709551615
#                         hist_id: Histogram ID with default -1
#                       n_entries: Number of entries in the histogram with default
#                                  -1
#                     bins_energy: array of energy bin lower edges, as in
#                                  np.histogram with default None [TeV]
#                  bins_core_dist: array of core-distance bin lower edges, as in
#                                  np.histogram with default None [m]
#                       histogram: array of histogram entries, size (n_bins_x,
#                                  n_bins_y) with default None,
#  np.int32(5778): ctapipe.containers.SimulatedShowerDistribution:
#                          obs_id: Observation Block ID with default
#                                  18446744073709551615
#                         hist_id: Histogram ID with default -1
#                       n_entries: Number of entries in the histogram with default
#                                  -1
#                     bins_energy: array of energy bin lower edges, as in
#                                  np.histogram with default None [TeV]
#                  bins_core_dist: array of core-distance bin lower edges, as in
#                                  np.histogram with default None [m]
#                       histogram: array of histogram entries, size (n_bins_x,
#                                  n_bins_y) with default None,
#  np.int32(5779): ctapipe.containers.SimulatedShowerDistribution:
#                          obs_id: Observation Block ID with default
#                                  18446744073709551615
#                         hist_id: Histogram ID with default -1
#                       n_entries: Number of entries in the histogram with default
#                                  -1
#                     bins_energy: array of energy bin lower edges, as in
#                                  np.histogram with default None [TeV]
#                  bins_core_dist: array of core-distance bin lower edges, as in
#                                  np.histogram with default None [m]
#                       histogram: array of histogram entries, size (n_bins_x,
#                                  n_bins_y) with default None,
#  np.int32(5781): ctapipe.containers.SimulatedShowerDistribution:
#                          obs_id: Observation Block ID with default
#                                  18446744073709551615
#                         hist_id: Histogram ID with default -1
#                       n_entries: Number of entries in the histogram with default
#                                  -1
#                     bins_energy: array of energy bin lower edges, as in
#                                  np.histogram with default None [TeV]
#                  bins_core_dist: array of core-distance bin lower edges, as in
#                                  np.histogram with default None [m]
#                       histogram: array of histogram entries, size (n_bins_x,
#                                  n_bins_y) with default None,
#  np.int32(5782): ctapipe.containers.SimulatedShowerDistribution:
#                          obs_id: Observation Block ID with default
#                                  18446744073709551615
#                         hist_id: Histogram ID with default -1
#                       n_entries: Number of entries in the histogram with default
#                                  -1
#                     bins_energy: array of energy bin lower edges, as in
#                                  np.histogram with default None [TeV]
#                  bins_core_dist: array of core-distance bin lower edges, as in
#                                  np.histogram with default None [m]
#                       histogram: array of histogram entries, size (n_bins_x,
#                                  n_bins_y) with default None,
#  np.int32(5784): ctapipe.containers.SimulatedShowerDistribution:
#                          obs_id: Observation Block ID with default
#                                  18446744073709551615
#                         hist_id: Histogram ID with default -1
#                       n_entries: Number of entries in the histogram with default
#                                  -1
#                     bins_energy: array of energy bin lower edges, as in
#                                  np.histogram with default None [TeV]
#                  bins_core_dist: array of core-distance bin lower edges, as in
#                                  np.histogram with default None [m]
#                       histogram: array of histogram entries, size (n_bins_x,
#                                  n_bins_y) with default None,
#  np.int32(5785): ctapipe.containers.SimulatedShowerDistribution:
#                          obs_id: Observation Block ID with default
#                                  18446744073709551615
#                         hist_id: Histogram ID with default -1
#                       n_entries: Number of entries in the histogram with default
#                                  -1
#                     bins_energy: array of energy bin lower edges, as in
#                                  np.histogram with default None [TeV]
#                  bins_core_dist: array of core-distance bin lower edges, as in
#                                  np.histogram with default None [m]
#                       histogram: array of histogram entries, size (n_bins_x,
#                                  n_bins_y) with default None,
#  np.int32(5786): ctapipe.containers.SimulatedShowerDistribution:
#                          obs_id: Observation Block ID with default
#                                  18446744073709551615
#                         hist_id: Histogram ID with default -1
#                       n_entries: Number of entries in the histogram with default
#                                  -1
#                     bins_energy: array of energy bin lower edges, as in
#                                  np.histogram with default None [TeV]
#                  bins_core_dist: array of core-distance bin lower edges, as in
#                                  np.histogram with default None [m]
#                       histogram: array of histogram entries, size (n_bins_x,
#                                  n_bins_y) with default None,
#  np.int32(5787): ctapipe.containers.SimulatedShowerDistribution:
#                          obs_id: Observation Block ID with default
#                                  18446744073709551615
#                         hist_id: Histogram ID with default -1
#                       n_entries: Number of entries in the histogram with default
#                                  -1
#                     bins_energy: array of energy bin lower edges, as in
#                                  np.histogram with default None [TeV]
#                  bins_core_dist: array of core-distance bin lower edges, as in
#                                  np.histogram with default None [m]
#                       histogram: array of histogram entries, size (n_bins_x,
#                                  n_bins_y) with default None,
#  np.int32(5793): ctapipe.containers.SimulatedShowerDistribution:
#                          obs_id: Observation Block ID with default
#                                  18446744073709551615
#                         hist_id: Histogram ID with default -1
#                       n_entries: Number of entries in the histogram with default
#                                  -1
#                     bins_energy: array of energy bin lower edges, as in
#                                  np.histogram with default None [TeV]
#                  bins_core_dist: array of core-distance bin lower edges, as in
#                                  np.histogram with default None [m]
#                       histogram: array of histogram entries, size (n_bins_x,
#                                  n_bins_y) with default None,
#  np.int32(5794): ctapipe.containers.SimulatedShowerDistribution:
#                          obs_id: Observation Block ID with default
#                                  18446744073709551615
#                         hist_id: Histogram ID with default -1
#                       n_entries: Number of entries in the histogram with default
#                                  -1
#                     bins_energy: array of energy bin lower edges, as in
#                                  np.histogram with default None [TeV]
#                  bins_core_dist: array of core-distance bin lower edges, as in
#                                  np.histogram with default None [m]
#                       histogram: array of histogram entries, size (n_bins_x,
#                                  n_bins_y) with default None,
#  np.int32(5800): ctapipe.containers.SimulatedShowerDistribution:
#                          obs_id: Observation Block ID with default
#                                  18446744073709551615
#                         hist_id: Histogram ID with default -1
#                       n_entries: Number of entries in the histogram with default
#                                  -1
#                     bins_energy: array of energy bin lower edges, as in
#                                  np.histogram with default None [TeV]
#                  bins_core_dist: array of core-distance bin lower edges, as in
#                                  np.histogram with default None [m]
#                       histogram: array of histogram entries, size (n_bins_x,
#                                  n_bins_y) with default None,
#  np.int32(5802): ctapipe.containers.SimulatedShowerDistribution:
#                          obs_id: Observation Block ID with default
#                                  18446744073709551615
#                         hist_id: Histogram ID with default -1
#                       n_entries: Number of entries in the histogram with default
#                                  -1
#                     bins_energy: array of energy bin lower edges, as in
#                                  np.histogram with default None [TeV]
#                  bins_core_dist: array of core-distance bin lower edges, as in
#                                  np.histogram with default None [m]
#                       histogram: array of histogram entries, size (n_bins_x,
#                                  n_bins_y) with default None,
#  np.int32(5805): ctapipe.containers.SimulatedShowerDistribution:
#                          obs_id: Observation Block ID with default
#                                  18446744073709551615
#                         hist_id: Histogram ID with default -1
#                       n_entries: Number of entries in the histogram with default
#                                  -1
#                     bins_energy: array of energy bin lower edges, as in
#                                  np.histogram with default None [TeV]
#                  bins_core_dist: array of core-distance bin lower edges, as in
#                                  np.histogram with default None [m]
#                       histogram: array of histogram entries, size (n_bins_x,
#                                  n_bins_y) with default None,
#  np.int32(5810): ctapipe.containers.SimulatedShowerDistribution:
#                          obs_id: Observation Block ID with default
#                                  18446744073709551615
#                         hist_id: Histogram ID with default -1
#                       n_entries: Number of entries in the histogram with default
#                                  -1
#                     bins_energy: array of energy bin lower edges, as in
#                                  np.histogram with default None [TeV]
#                  bins_core_dist: array of core-distance bin lower edges, as in
#                                  np.histogram with default None [m]
#                       histogram: array of histogram entries, size (n_bins_x,
#                                  n_bins_y) with default None,
#  np.int32(5815): ctapipe.containers.SimulatedShowerDistribution:
#                          obs_id: Observation Block ID with default
#                                  18446744073709551615
#                         hist_id: Histogram ID with default -1
#                       n_entries: Number of entries in the histogram with default
#                                  -1
#                     bins_energy: array of energy bin lower edges, as in
#                                  np.histogram with default None [TeV]
#                  bins_core_dist: array of core-distance bin lower edges, as in
#                                  np.histogram with default None [m]
#                       histogram: array of histogram entries, size (n_bins_x,
#                                  n_bins_y) with default None,
#  np.int32(5817): ctapipe.containers.SimulatedShowerDistribution:
#                          obs_id: Observation Block ID with default
#                                  18446744073709551615
#                         hist_id: Histogram ID with default -1
#                       n_entries: Number of entries in the histogram with default
#                                  -1
#                     bins_energy: array of energy bin lower edges, as in
#                                  np.histogram with default None [TeV]
#                  bins_core_dist: array of core-distance bin lower edges, as in
#                                  np.histogram with default None [m]
#                       histogram: array of histogram entries, size (n_bins_x,
#                                  n_bins_y) with default None,
#  np.int32(5818): ctapipe.containers.SimulatedShowerDistribution:
#                          obs_id: Observation Block ID with default
#                                  18446744073709551615
#                         hist_id: Histogram ID with default -1
#                       n_entries: Number of entries in the histogram with default
#                                  -1
#                     bins_energy: array of energy bin lower edges, as in
#                                  np.histogram with default None [TeV]
#                  bins_core_dist: array of core-distance bin lower edges, as in
#                                  np.histogram with default None [m]
#                       histogram: array of histogram entries, size (n_bins_x,
#                                  n_bins_y) with default None,
#  np.int32(5827): ctapipe.containers.SimulatedShowerDistribution:
#                          obs_id: Observation Block ID with default
#                                  18446744073709551615
#                         hist_id: Histogram ID with default -1
#                       n_entries: Number of entries in the histogram with default
#                                  -1
#                     bins_energy: array of energy bin lower edges, as in
#                                  np.histogram with default None [TeV]
#                  bins_core_dist: array of core-distance bin lower edges, as in
#                                  np.histogram with default None [m]
#                       histogram: array of histogram entries, size (n_bins_x,
#                                  n_bins_y) with default None,
#  np.int32(5829): ctapipe.containers.SimulatedShowerDistribution:
#                          obs_id: Observation Block ID with default
#                                  18446744073709551615
#                         hist_id: Histogram ID with default -1
#                       n_entries: Number of entries in the histogram with default
#                                  -1
#                     bins_energy: array of energy bin lower edges, as in
#                                  np.histogram with default None [TeV]
#                  bins_core_dist: array of core-distance bin lower edges, as in
#                                  np.histogram with default None [m]
#                       histogram: array of histogram entries, size (n_bins_x,
#                                  n_bins_y) with default None,
#  np.int32(5841): ctapipe.containers.SimulatedShowerDistribution:
#                          obs_id: Observation Block ID with default
#                                  18446744073709551615
#                         hist_id: Histogram ID with default -1
#                       n_entries: Number of entries in the histogram with default
#                                  -1
#                     bins_energy: array of energy bin lower edges, as in
#                                  np.histogram with default None [TeV]
#                  bins_core_dist: array of core-distance bin lower edges, as in
#                                  np.histogram with default None [m]
#                       histogram: array of histogram entries, size (n_bins_x,
#                                  n_bins_y) with default None,
#  np.int32(5845): ctapipe.containers.SimulatedShowerDistribution:
#                          obs_id: Observation Block ID with default
#                                  18446744073709551615
#                         hist_id: Histogram ID with default -1
#                       n_entries: Number of entries in the histogram with default
#                                  -1
#                     bins_energy: array of energy bin lower edges, as in
#                                  np.histogram with default None [TeV]
#                  bins_core_dist: array of core-distance bin lower edges, as in
#                                  np.histogram with default None [m]
#                       histogram: array of histogram entries, size (n_bins_x,
#                                  n_bins_y) with default None,
#  np.int32(5846): ctapipe.containers.SimulatedShowerDistribution:
#                          obs_id: Observation Block ID with default
#                                  18446744073709551615
#                         hist_id: Histogram ID with default -1
#                       n_entries: Number of entries in the histogram with default
#                                  -1
#                     bins_energy: array of energy bin lower edges, as in
#                                  np.histogram with default None [TeV]
#                  bins_core_dist: array of core-distance bin lower edges, as in
#                                  np.histogram with default None [m]
#                       histogram: array of histogram entries, size (n_bins_x,
#                                  n_bins_y) with default None,
#  np.int32(5851): ctapipe.containers.SimulatedShowerDistribution:
#                          obs_id: Observation Block ID with default
#                                  18446744073709551615
#                         hist_id: Histogram ID with default -1
#                       n_entries: Number of entries in the histogram with default
#                                  -1
#                     bins_energy: array of energy bin lower edges, as in
#                                  np.histogram with default None [TeV]
#                  bins_core_dist: array of core-distance bin lower edges, as in
#                                  np.histogram with default None [m]
#                       histogram: array of histogram entries, size (n_bins_x,
#                                  n_bins_y) with default None,
#  np.int32(5861): ctapipe.containers.SimulatedShowerDistribution:
#                          obs_id: Observation Block ID with default
#                                  18446744073709551615
#                         hist_id: Histogram ID with default -1
#                       n_entries: Number of entries in the histogram with default
#                                  -1
#                     bins_energy: array of energy bin lower edges, as in
#                                  np.histogram with default None [TeV]
#                  bins_core_dist: array of core-distance bin lower edges, as in
#                                  np.histogram with default None [m]
#                       histogram: array of histogram entries, size (n_bins_x,
#                                  n_bins_y) with default None,
#  np.int32(5863): ctapipe.containers.SimulatedShowerDistribution:
#                          obs_id: Observation Block ID with default
#                                  18446744073709551615
#                         hist_id: Histogram ID with default -1
#                       n_entries: Number of entries in the histogram with default
#                                  -1
#                     bins_energy: array of energy bin lower edges, as in
#                                  np.histogram with default None [TeV]
#                  bins_core_dist: array of core-distance bin lower edges, as in
#                                  np.histogram with default None [m]
#                       histogram: array of histogram entries, size (n_bins_x,
#                                  n_bins_y) with default None,
#  np.int32(5872): ctapipe.containers.SimulatedShowerDistribution:
#                          obs_id: Observation Block ID with default
#                                  18446744073709551615
#                         hist_id: Histogram ID with default -1
#                       n_entries: Number of entries in the histogram with default
#                                  -1
#                     bins_energy: array of energy bin lower edges, as in
#                                  np.histogram with default None [TeV]
#                  bins_core_dist: array of core-distance bin lower edges, as in
#                                  np.histogram with default None [m]
#                       histogram: array of histogram entries, size (n_bins_x,
#                                  n_bins_y) with default None,
#  np.int32(5876): ctapipe.containers.SimulatedShowerDistribution:
#                          obs_id: Observation Block ID with default
#                                  18446744073709551615
#                         hist_id: Histogram ID with default -1
#                       n_entries: Number of entries in the histogram with default
#                                  -1
#                     bins_energy: array of energy bin lower edges, as in
#                                  np.histogram with default None [TeV]
#                  bins_core_dist: array of core-distance bin lower edges, as in
#                                  np.histogram with default None [m]
#                       histogram: array of histogram entries, size (n_bins_x,
#                                  n_bins_y) with default None,
#  np.int32(5877): ctapipe.containers.SimulatedShowerDistribution:
#                          obs_id: Observation Block ID with default
#                                  18446744073709551615
#                         hist_id: Histogram ID with default -1
#                       n_entries: Number of entries in the histogram with default
#                                  -1
#                     bins_energy: array of energy bin lower edges, as in
#                                  np.histogram with default None [TeV]
#                  bins_core_dist: array of core-distance bin lower edges, as in
#                                  np.histogram with default None [m]
#                       histogram: array of histogram entries, size (n_bins_x,
#                                  n_bins_y) with default None,
#  np.int32(5879): ctapipe.containers.SimulatedShowerDistribution:
#                          obs_id: Observation Block ID with default
#                                  18446744073709551615
#                         hist_id: Histogram ID with default -1
#                       n_entries: Number of entries in the histogram with default
#                                  -1
#                     bins_energy: array of energy bin lower edges, as in
#                                  np.histogram with default None [TeV]
#                  bins_core_dist: array of core-distance bin lower edges, as in
#                                  np.histogram with default None [m]
#                       histogram: array of histogram entries, size (n_bins_x,
#                                  n_bins_y) with default None,
#  np.int32(5883): ctapipe.containers.SimulatedShowerDistribution:
#                          obs_id: Observation Block ID with default
#                                  18446744073709551615
#                         hist_id: Histogram ID with default -1
#                       n_entries: Number of entries in the histogram with default
#                                  -1
#                     bins_energy: array of energy bin lower edges, as in
#                                  np.histogram with default None [TeV]
#                  bins_core_dist: array of core-distance bin lower edges, as in
#                                  np.histogram with default None [m]
#                       histogram: array of histogram entries, size (n_bins_x,
#                                  n_bins_y) with default None,
#  np.int32(5887): ctapipe.containers.SimulatedShowerDistribution:
#                          obs_id: Observation Block ID with default
#                                  18446744073709551615
#                         hist_id: Histogram ID with default -1
#                       n_entries: Number of entries in the histogram with default
#                                  -1
#                     bins_energy: array of energy bin lower edges, as in
#                                  np.histogram with default None [TeV]
#                  bins_core_dist: array of core-distance bin lower edges, as in
#                                  np.histogram with default None [m]
#                       histogram: array of histogram entries, size (n_bins_x,
#                                  n_bins_y) with default None,
#  np.int32(5901): ctapipe.containers.SimulatedShowerDistribution:
#                          obs_id: Observation Block ID with default
#                                  18446744073709551615
#                         hist_id: Histogram ID with default -1
#                       n_entries: Number of entries in the histogram with default
#                                  -1
#                     bins_energy: array of energy bin lower edges, as in
#                                  np.histogram with default None [TeV]
#                  bins_core_dist: array of core-distance bin lower edges, as in
#                                  np.histogram with default None [m]
#                       histogram: array of histogram entries, size (n_bins_x,
#                                  n_bins_y) with default None,
#  np.int32(5905): ctapipe.containers.SimulatedShowerDistribution:
#                          obs_id: Observation Block ID with default
#                                  18446744073709551615
#                         hist_id: Histogram ID with default -1
#                       n_entries: Number of entries in the histogram with default
#                                  -1
#                     bins_energy: array of energy bin lower edges, as in
#                                  np.histogram with default None [TeV]
#                  bins_core_dist: array of core-distance bin lower edges, as in
#                                  np.histogram with default None [m]
#                       histogram: array of histogram entries, size (n_bins_x,
#                                  n_bins_y) with default None,
#  np.int32(5906): ctapipe.containers.SimulatedShowerDistribution:
#                          obs_id: Observation Block ID with default
#                                  18446744073709551615
#                         hist_id: Histogram ID with default -1
#                       n_entries: Number of entries in the histogram with default
#                                  -1
#                     bins_energy: array of energy bin lower edges, as in
#                                  np.histogram with default None [TeV]
#                  bins_core_dist: array of core-distance bin lower edges, as in
#                                  np.histogram with default None [m]
#                       histogram: array of histogram entries, size (n_bins_x,
#                                  n_bins_y) with default None,
#  np.int32(5912): ctapipe.containers.SimulatedShowerDistribution:
#                          obs_id: Observation Block ID with default
#                                  18446744073709551615
#                         hist_id: Histogram ID with default -1
#                       n_entries: Number of entries in the histogram with default
#                                  -1
#                     bins_energy: array of energy bin lower edges, as in
#                                  np.histogram with default None [TeV]
#                  bins_core_dist: array of core-distance bin lower edges, as in
#                                  np.histogram with default None [m]
#                       histogram: array of histogram entries, size (n_bins_x,
#                                  n_bins_y) with default None}

# %%
bins_dist = dist["bins_core_dist"]        
bins_e = dist["bins_energy"]      
hist2d = dist["histogram"]             

# Marginalize over energy and distance parameters to get 1D distributions

hist_r = hist2d.sum(axis=0)
hist_e = hist2d.sum(axis=1)

r_edges = bins_dist.to_value()  
r_centers = 0.5 * (r_edges[:-1] + r_edges[1:])
e_centers = 0.5 * (bins_e[:-1] + bins_e[1:])

fig, ax = plt.subplots(1, 2, figsize=(12, 4))

plt.suptitle(f"Simulated shower distributions for Observation ID {obs_id}", fontsize=16)
ax[0].step(r_centers, hist_r, where="mid")
ax[0].set_xlabel("Shower core distance [m]")
ax[0].set_ylabel("Number of simulated showers")
ax[0].set_title("Simulated shower core distance distribution")
ax[0].grid(alpha=0.3)



ax[1].step(e_centers, hist_e, where="mid")
ax[1].set_xlabel("Shower energy [TeV]")
ax[1].set_ylabel("Number of simulated showers")
ax[1].set_title("Simulated shower energy distribution")
ax[1].grid(alpha=0.3)
ax[1].set_xscale("log")
ax[1].set_yscale("log")
plt.tight_layout()
plt.show()

# %%
dist.n_entries
# Out:
# np.int64(1000000)

# %%
dist.hist_id
# Out:
# np.int64(6)
